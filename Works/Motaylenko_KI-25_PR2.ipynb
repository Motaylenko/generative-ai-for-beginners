# %% [markdown]
# # Вступ до інженерії промптів
# Інженерія промптів - це процес розробки та оптимізації промптів для завдань обробки природної мови. Він включає вибір правильних промптів, налаштування їхніх параметрів та оцінку їх ефективності. Інженерія промптів є критично важливою для досягнення високої точності та ефективності в моделях NLP. У цьому розділі ми дослідимо основи інженерії промптів, використовуючи моделі OpenAI для експериментів.

# %% [markdown]
# ### Вправа 1: Токенізація
# Дослідіть токенізацію за допомогою tiktoken - швидкого токенізатора з відкритим кодом від OpenAI
# Дивіться [OpenAI Cookbook](https://github.com/openai/openai-cookbook/blob/main/examples/How_to_count_tokens_with_tiktoken.ipynb?WT.mc_id=academic-105485-koreyst) для додаткових прикладів.

# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.7 kB)
# Collecting regex>=2022.1.18 (from tiktoken)
#   Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests>=2.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken) (2025.4.26)
# Downloading tiktoken-0.12.0-cp312-cp312-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.6 MB/s eta 0:00:00
# Downloading regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.5/803.5 kB 33.3 MB/s eta 0:00:00
# Installing collected packages: regex, tiktoken
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [tiktoken]
# Successfully installed regex-2025.11.3 tiktoken-0.12.0
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# ВПРАВА:
# 1. Спочатку запустіть вправу як є
# 2. Змініть текст на будь-який промпт, який ви хочете використати, і перезапустіть, щоб побачити токени

import tiktoken

# Визначте промпт, який ви хочете токенізувати
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

# Set the model you want encoding for
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

# Encode the text - gives you the tokens in integer form
tokens = encoding.encode(text)
print(tokens);

# Decode the integers to see what the text versions look like
[encoding.decode_single_token_bytes(token) for token in tokens]
# Out:
# [198, 140, 106, 8164, 27385, 58060, 482, 5173, 6, 4329, 44613, 5173, 3114, 7486, 8341, 1506, 5927, 27385, 7094, 28599, 17766, 10589, 4329, 84954, 6850, 19039, 10124, 27385, 29118, 12426, 1506, 5927, 28599, 17766, 4329, 6148, 2156, 27385, 12415, 93099, 27385, 13, 1301, 99, 1532, 25756, 19188, 6856, 44938, 25756, 27385, 15752, 7486, 1830, 11122, 11562, 18437, 1482, 12182, 5927, 53419, 2156, 3865, 11047, 13810, 4329, 6148, 2156, 3865, 5927, 27385, 7094, 11562, 18437, 1840, 28599, 17766, 10589, 4329, 11, 21022, 3114, 1532, 5927, 74254, 1506, 11122, 29619, 6856, 1840, 13999, 12182, 39479, 1840, 14391, 27385, 29118, 12426, 1482, 12182, 44946, 11562, 18437, 3865, 35714, 27385, 10693, 84954, 2156, 30480, 10693, 5173, 3114, 7486, 8341, 28599, 17766, 4329, 6148, 13999, 141, 245, 93099, 1840, 39479, 12507, 14257, 9136, 4329, 23311, 10693, 13, 1301, 106, 8164, 27385, 58060, 482, 53419, 19479, 11122, 6850, 19039, 4329, 66144, 28086, 27385, 30480, 10693, 21923, 6, 141, 242, 4898, 1830, 27385, 5591, 11, 74020, 16494, 67745, 19175, 20219, 10124, 2233, 1482, 141, 242, 2156, 16494, 72664, 12507, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 11, 84954, 14391, 3865, 5591, 5927, 27385, 7094, 12507, 44938, 18868, 17721, 9706, 18226, 2156, 27385, 6578, 39233, 28089, 27385, 3114, 27385, 9136, 1506, 10589, 27385, 4329, 6578, 9015, 231, 1532, 57297, 5173, 13810, 7486, 1482, 141, 245, 84954, 6735, 9239, 27385, 141, 245, 13, 23784, 27385, 2156, 6850, 57059, 14332, 12415, 13373, 17756, 1532, 35592, 18600, 16494, 2297, 4929, 4898, 22885, 14391, 14837, 1506, 1301, 106, 8164, 27385, 58060, 1506, 8032, 777, 60, 23227, 31203, 84714, 25262, 7753, 50436, 5372, 2156, 27385, 11122, 53677, 10298, 3114, 27385, 1301, 106, 8164, 27385, 58060, 45583, 1532, 14391, 3865, 23311, 13373, 6735, 27385, 29118, 17165, 46410, 66144, 28086, 16494, 11, 9015, 231, 1482, 1301, 117, 22885, 5927, 27385, 7094, 10124, 27055, 45916, 27385, 1830, 39865, 45583, 1532, 5927, 27385, 7094, 17165, 7094, 8131, 1840, 74020, 16494, 27385, 11047, 27385, 2156, 27385, 17706, 508, 60, 84954, 5927, 66386, 13404, 2156, 4929, 72952, 5927, 27385, 2156, 9015, 242, 86995, 8341, 27385, 6578, 44946, 46410, 66144, 28086, 27385, 6735, 12182, 37405, 2233, 9706, 2156, 16494, 21923, 6, 141, 242, 4898, 94866, 13373, 6850, 27385, 6148, 2156, 72952, 6850, 50693, 27385, 5173, 27385, 2297, 14009, 45458, 27385, 21204, 10589, 4329, 11047, 1506, 23784, 5372, 7753, 1840, 627]
# [b'\n',
#  b'\xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbf',
#  b"'",
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb0',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x96',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xb0',
#  b' \xd0\xb2',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xb9',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd1\x96',
#  b'.',
#  b' \xd0',
#  b'\xa6',
#  b'\xd0\xb5',
#  b' \xd0\xb3',
#  b'\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd0\xb3',
#  b'\xd1\x96',
#  b'\xd0\xb3',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd1\x82',
#  b' \xd0\xb7',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb2',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd1\x82',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd0\xb8',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b',',
#  b' \xd0\xb0',
#  b'\xd0\xbb',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b' \xd0\xb4\xd0\xb2',
#  b'\xd0\xb0',
#  b' \xd0\xb7',
#  b' \xd0\xbf\xd0\xbe\xd0\xbb',
#  b'\xd0\xbe\xd0\xb2',
#  b'\xd0\xb8',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xb8',
#  b' \xd0\xb1',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd1\x88',
#  b'\xd0\xbe',
#  b'\xd1\x8e',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd0\xbc',
#  b'\xd0\xb0\xd1\x81',
#  b'\xd1\x83',
#  b' \xd0\xb2\xd1\x81',
#  b'\xd1\x96',
#  b'\xd1\x85',
#  b' \xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbf',
#  b'\xd0\xbb',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xb5\xd1\x82',
#  b' \xd0\xa1',
#  b'\xd0\xbe\xd0\xbd',
#  b'\xd1\x8f',
#  b'\xd1\x87',
#  b'\xd0\xbd\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x81\xd0\xb8\xd1\x81\xd1\x82\xd0\xb5\xd0\xbc',
#  b'\xd0\xb8',
#  b' \xd1\x80\xd0\xb0\xd0\xb7',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd1\x83',
#  b'\xd0\xb7',
#  b'\xd1\x8f',
#  b'\xd1\x82\xd0\xb8',
#  b'\xd1\x85',
#  b'.',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' -',
#  b' \xd0\xbe\xd0\xb4',
#  b'\xd0\xb8\xd0\xbd',
#  b' \xd0\xb7',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb9',
#  b'\xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x88\xd0\xb8',
#  b'\xd1\x85',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xb2',
#  b',',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd0\xb8\xd1\x85',
#  b' \xd0\xbd\xd0\xb5',
#  b'\xd0\xbe\xd0\xb7',
#  b'\xd0\xb1',
#  b'\xd1\x80',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xba',
#  b'\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b',',
#  b' \xd1\x96',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd0\xb2',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xbe\xd0\xbc',
#  b'\xd0\xb8\xd0\xb9',
#  b' \xd1\x81\xd1\x82',
#  b'\xd0\xb0\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xb0\xd0\xb2',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd1\x86',
#  b'\xd0\xb8\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b'\xd0\xb7',
#  b'\xd0\xb0',
#  b'\xd1\x86',
#  b'\xd1\x96',
#  b'\xd1\x8f',
#  b'\xd0\xbc',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xb5',
#  b' \xd0\xb4\xd0\xbe',
#  b' \xd0\xbf',
#  b'\xd0\xb8\xd1\x81',
#  b'\xd0\xb0\xd0\xbd',
#  b'\xd0\xbe',
#  b'\xd1',
#  b'\x97',
#  b' \xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd0\xbe\xd1\x80',
#  b'\xd1\x96',
#  b'\xd1',
#  b'\x97',
#  b'.',
#  b' \xd0\x92',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd0\xbd',
#  b'\xd0\xb0\xd0\xb7\xd0\xb2',
#  b'\xd0\xb0\xd0\xbd\xd0\xb8',
#  b'\xd0\xb9',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd1\x87',
#  b'\xd0\xb5',
#  b'\xd1\x81\xd1\x82\xd1\x8c',
#  b' \xd1\x80',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x81',
#  b'\xd1\x8c',
#  b'\xd0\xba',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb1',
#  b'\xd0\xbe\xd0\xb3',
#  b'\xd0\xb0',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b'\xd0\xb0',
#  b'.[',
#  b'19',
#  b']',
#  b' \xd0\x9f',
#  b'\xd1\x80\xd0\xb8',
#  b' \xd1\x81\xd0\xbf',
#  b'\xd0\xbe\xd1\x81\xd1\x82',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb6',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b' \xd0\xb7',
#  b' \xd0\x97',
#  b'\xd0\xb5\xd0\xbc',
#  b'\xd0\xbb',
#  b'\xd1\x96',
#  b' \xd0',
#  b'\xae',
#  b'\xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x82\xd0\xb5\xd1\x80',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb1',
#  b'\xd1\x83',
#  b'\xd1\x82\xd0\xb8',
#  b' \xd0\xbd\xd0\xb0',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbb\xd1\x8c',
#  b'\xd0\xba\xd0\xb8',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd0\xb8\xd0\xbc',
#  b',',
#  b' \xd1',
#  b'\x89',
#  b'\xd0\xbe',
#  b' \xd0',
#  b'\xb9',
#  b'\xd0\xbe\xd0\xb3\xd0\xbe',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xb1',
#  b'\xd0\xb8\xd1\x82\xd0\xb5',
#  b' \xd1\x81\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x82',
#  b'\xd0\xbb\xd0\xbe',
#  b' \xd0\xbc\xd0\xbe\xd0\xb6',
#  b'\xd0\xb5',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xb4',
#  b'\xd0\xba\xd0\xb8',
#  b'\xd0\xb4',
#  b'\xd0\xb0\xd1\x82',
#  b'\xd0\xb8',
#  b' \xd0\xb2\xd0\xb8\xd0\xb4',
#  b'\xd0\xb8\xd0\xbc',
#  b'\xd1\x96',
#  b' \xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b'\xd1\x96',
#  b',[',
#  b'20',
#  b']',
#  b' \xd1\x96',
#  b' \xd0\xb2',
#  b' \xd1\x81\xd0\xb5\xd1\x80',
#  b'\xd0\xb5\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd1\x8c',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xb2',
#  b'\xd1\x96',
#  b'\xd0\xbd',
#  b' \xd1',
#  b'\x94',
#  b' \xd1\x82\xd1\x80',
#  b'\xd0\xb5\xd1\x82',
#  b'\xd1\x96',
#  b'\xd0\xbc',
#  b' \xd0\xb7\xd0\xb0',
#  b' \xd1\x8f',
#  b'\xd1\x81\xd0\xba',
#  b'\xd1\x80\xd0\xb0\xd0\xb2',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x82',
#  b'\xd1\x8e',
#  b' \xd0\xbf\xd1\x80\xd0\xb8',
#  b'\xd1\x80',
#  b'\xd0\xbe\xd0\xb4',
#  b'\xd0\xbd',
#  b'\xd0\xb8\xd0\xbc',
#  b' \xd0\xbe\xd0\xb1',
#  b"'",
#  b'\xd1',
#  b'\x94',
#  b'\xd0\xba',
#  b'\xd1\x82\xd0\xbe\xd0\xbc',
#  b' \xd0\xbd\xd0\xb0',
#  b' \xd0\xbd',
#  b'\xd1\x96',
#  b'\xd1\x87',
#  b'\xd0\xbd',
#  b'\xd0\xbe\xd0\xbc\xd1\x83',
#  b' \xd0\xbd',
#  b'\xd0\xb5\xd0\xb1',
#  b'\xd1\x96',
#  b' \xd0\xbf',
#  b'\xd1\x96',
#  b'\xd1\x81',
#  b'\xd0\xbb\xd1\x8f',
#  b' \xd0\x9c',
#  b'\xd1\x96',
#  b'\xd1\x81\xd1\x8f',
#  b'\xd1\x86',
#  b'\xd1\x8f',
#  b' \xd1\x82',
#  b'\xd0\xb0',
#  b' \xd0\x92',
#  b'\xd0\xb5\xd0\xbd',
#  b'\xd0\xb5\xd1\x80',
#  b'\xd0\xb8',
#  b'.\n']

# %% [markdown]
# ### Вправа 2: Перевірка налаштування ключа Github Models
#
# Запустіть код нижче, щоб перевірити, чи правильно налаштована кінцева точка Github Models. Код просто випробовує простий базовий промпт і перевіряє завершення. Вхідний текст `о скажи, чи бачиш ти` має завершитись відповідно до контексту.

# %%
# !pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.0.0b9)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.4.26)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.inference.ai.azure.com"

model_name = "gpt-4o"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

def get_completion(prompt, client, model_name, temperature=1.0, max_tokens=1000, top_p=1.0):
    response = client.complete(
        messages=[
            {
                "role": "system",
                "content": "Ви - корисний асистент.",
            },
            {
                "role": "user",
                "content": prompt,
            },
        ],
        model=model_name,
        temperature=temperature,
        max_tokens=max_tokens,
        top_p=top_p
    )
    return response.choices[0].message.content

## ---------- Виклик допоміжного методу

### 1. Встановіть основний вміст або текст промпту
text = f"""
о скажи, чи бачиш ти
"""

### 2. Використайте його в шаблоні промпту нижче
prompt = f"""
```{text}```
"""

## 3. Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Це, мабуть, початок вірша або рядок з пісні. Чи бажаєте, щоб я допоміг вам продовжити текст?

# %% [markdown]
# ### Вправа 3: Вигадки
# Дослідіть, що відбувається, коли ви просите LLM повернути завершення для промпту про тему, яка може не існувати, або про теми, про які вона може не знати, оскільки вони були за межами її попередньо навченого набору даних (більш пізні). Подивіться, як змінюється відповідь, якщо ви спробуєте інший промпт або іншу модель.

# %%
## Встановіть текст для простого промпту або основного вмісту
## Промпт показує формат шаблону з текстом - додайте підказки, команди тощо, якщо потрібно
## Запустіть завершення
text = f"""
створіть план уроку про Марсіанську війну 2076 року.
"""

prompt = f"""
```{text}```
"""
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Марсіанська війна 2076 року є вигаданою темою, яка може стати цікавим матеріалом для креативного уроку з історії, літератури або навіть фантазійного футурологічного мислення. Ось детальний план уроку, який може надихнути учнів досліджувати альтернативну історію та розвивати критичне і творче мислення:
#
# ---
#
# ## **План уроку: Марсіанська війна 2076 року**
#
# ### **Мета уроку**:
# 1. Розвинути уяву та креативне мислення учнів, запропонувавши їм створити власну версію футуристичної історії.
# 2. Поглибити розуміння сучасних наукових і технічних досягнень, які можуть вплинути на майбутні конфлікти.
# 3. Навчити аналізувати соціальні, політичні та екологічні фактори, що могли б спричинити міжпланетний конфлікт.
#
# ---
#
# ### **1. Вступ (10 хвилин)**
# - **Учитель каже**:
#   "Сьогодні ми вирушимо у майбутнє і дослідимо вигадану подію — Марсіанську війну 2076 року. Як ви уявляєте життя людей на Марсі? Чому життя на Марсі може призвести до конфлікту?"
# - **Питання до класу**:
#   - Що вам відомо про колонізацію Марсу?
#   - Як ви думаєте, які ресурси або ідеї можуть призвести до війни між Землею та Марсом?
#
# ---
#
# ### **2. Теоретична частина: Історія війни (15 хвилин)**
# - **Вигадана довідка** (пояснює вчитель або демонструється презентація):
#   - У 2076 році людство вже протягом 50 років успішно заселило Марс. На планеті було створено автономні міста, які більше не залежали від Землі. Але напруженість між марсіанськими колоністами і урядами Землі стала причиною війни.
#   - Основні причини конфлікту:
#     - Боротьба за ресурси (вода, мінерали, енергія).
#     - Незалежність Марса від Землі (політичні конфлікти).
#     - Екологічна криза, яка змушує Землю звернутися до Марса.
#
# ---
#
# ### **3. Групова робота: Створення сценарію війни (20 хвилин)**
# - **Поділ класу на 3 групи**:
#   - **Група 1**: Досліджує причини війни між Землею і Марсом.
#   - **Група 2**: Пропонує опис військових технологій 2076 року (наприклад: кораблі, роботи, штучний інтелект).
#   - **Група 3**: Розробляє історію марсіанських колоністів та їхній шлях до незалежності.
#
# #### Приклад роботи груп:
# - **Група 1** може створити список причин конфлікту: екологічні кризи, суперечки за ресурси, різниця у політичному устрої.
# - **Група 2** може намалювати або описати "майбутні військові технології", як-от дрони для міжпланетних боїв, пілотовані космічні кораблі або штучний інтелект.
# - **Група 3** може написати заяву для марсіанського уряду, яка оголошує незалежність від Землі.
#
# ---
#
# ### **4. Дебати: Хто правий у війні? (15 хвилин)**
# - **Після групової роботи учні обговорюють**:
#   - Земля чи Марс — хто правий у цьому конфлікті? Чи виправдана війна?
#   - Як можна вирішити конфлікт мирним шляхом?
#   - Чи варто Марсу ставати незалежною планетою?
#
# ---
#
# ### **5. Заключне обговорення і рефлексія (10 хвилин)**
# - Запитати учнів:
#   - Що ви дізналися про потенційні можливості розвитку людства у космосі?
#   - Як

# %% [markdown]
# ### Вправа 4: На основі інструкцій
# Використовуйте змінну "text" для встановлення основного вмісту
# та змінну "prompt" для надання інструкції, пов'язаної з цим основним вмістом.
#
# Тут ми просимо модель підсумувати текст для учня другого класу

# %%
# Тестовий приклад
# https://platform.openai.com/playground/p/default-summarize

## Приклад тексту
text = f"""
Юпітер - п'ята планета від Сонця і найбільша \
в Сонячній системі. Це газовий гігант з масою \
в одну тисячну від маси Сонця, але в два з половиною \
рази більшою за масу всіх інших планет Сонячної системи разом узятих. \
Юпітер - один з найяскравіших об'єктів, видимих неозброєним оком \
на нічному небі, і був відомий стародавнім цивілізаціям ще \
до писаної історії. Він названий на честь римського бога Юпітера.[19] \
При спостереженні з Землі Юпітер може бути настільки яскравим, що його відбите \
світло може відкидати видимі тіні,[20] і в середньому він є третім за яскравістю \
природним об'єктом на нічному небі після Місяця та Венери.
"""

## Встановіть промпт
prompt = f"""
Підсумуйте наданий вам контент для учня другого класу.
```{text}```
"""

## Запустіть промпт
response = get_completion(prompt, client, model_name)
print(response)
# Out:
# Юпітер – це п’ята планета від Сонця і найбільша в нашій Сонячній системі. Він настільки масивний, що важчий за всі інші планети разом узяті. Це газовий гігант, і його можна побачити на нічному небі без телескопа, бо він дуже яскравий – навіть може відкидати тіні. Юпітер названий на честь римського бога і є однією з найяскравіших планет, яку люди знають ще з давніх часів.

# %% [markdown]
# ### Вправа 5: Складний промпт
# Спробуйте запит, який має системні повідомлення, повідомлення користувача та асистента
# Система встановлює контекст асистента
# Повідомлення користувача і асистента забезпечують контекст багатокрокової розмови
#
# Зверніть увагу, як особистість асистента встановлена як "саркастична" в системному контексті.
# Спробуйте використати інший контекст особистості. Або спробуйте іншу серію повідомлень вводу/виводу

# %% [markdown]
# ### Вправа: Дослідіть свою інтуїцію
# Наведені вище приклади дають вам шаблони, які ви можете використовувати для створення нових промптів (простих, складних, інструкційних тощо) - спробуйте створити інші вправи для дослідження деяких інших ідей, про які ми говорили, таких як приклади, підказки та інше.

# %% [markdown]
# ### Індивідуальне завдання

# %%
# Prompt template: аналіз дампів пам'яті x86 / ARM (форензика / відлагодження)
# Використовує наявну функцію get_completion, клієнт `client` і модель `model_name`.

text = f"""
Ви — експерт з аналізу дампів пам'яті (x86, x86_64, ARM, ARM64) для цілей відлагодження та цифрової форензики.
Інструкція: проаналізуй наданий дамп пам'яті та поверни структурований звіт у форматі JSON з такими полями:
- architecture: одна з [x86, x86_64, arm, arm64, unknown] з коротким поясненням.
- endianness: [little, big, unknown].
- pointer_size: [32, 64, unknown].
- probable_image_headers: знайдені заголовки (PE, ELF, Mach-O) з офсетами та кратким контекстом.
- mapped_modules: імена або ймовірні бібліотеки/модулі з базовими адресами (якщо видно).
- extracted_strings: значущі рядки з офсетами (URL, шляхи, команди, потенційні облікові дані) — лише вилучені дані.
- suspicious_regions: список офсетів з коротким описом (напр., потенційний шелкод, стиснені/зашифровані блоки, незвична виконавча пам'ять) — без інструкцій з експлуатації.
- probable_code_snippets: для 2–3 найцікавіших блоків наведи невелику дизасембльовану або інструкційну інтерпретацію (вкажи архітектуру й офсет).
- confidence: оцінка впевненості для кожного великого висновку (low/medium/high).
- recommendations: безпечні кроки для подальшого розслідування (інструменти та методи перевірки), без інструкцій щодо зловживань.

Додаткові умови:
- Першим виведи тільки валідний JSON (без додаткового тексту).
- Після JSON додай 2–3 речення з коротким резюме найважливіших знахідок.
- Не надавай інструкцій щодо експлуатації, створення або використання шкідливого коду.
"""

prompt = f"""
Проаналізуй дамп відповідно до інструкції нижче і поверни JSON звіт + коротке резюме.
# Out:
#   Cell In[1], line 24
#     prompt = f"""
#              ^
# SyntaxError: unterminated triple-quoted f-string literal (detected at line 25)
