# %% [markdown]
# # Розділ 7: Створення чат-додатків
# ## Швидкий старт з API моделей Github
#
# Цей ноутбук адаптовано з [репозиторію прикладів Azure OpenAI](https://github.com/Azure/azure-openai-samples?WT.mc_id=academic-105485-koreyst), який включає ноутбуки для доступу до сервісів [Azure OpenAI](notebook-azure-openai.ipynb).
#
# # Огляд
# "Великі мовні моделі - це функції, які перетворюють текст на текст. Отримавши вхідний рядок тексту, велика мовна модель намагається передбачити текст, який ітиме далі"(1). Цей "швидкий старт" познайомить користувачів з концепціями LLM високого рівня, основними вимогами пакетів для початку роботи з AML, м'яким введенням у дизайн промптів та кількома короткими прикладами різних випадків використання.
#
# ## Зміст
#
# [Огляд](#огляд)
# [Як використовувати сервіс OpenAI](#як-використовувати-сервіс-openai)
# [1. Створення вашого сервісу OpenAI](#1.-створення-вашого-сервісу-openai)
# [2. Встановлення](#2.-встановлення)
# [3. Облікові дані](#3.-облікові-дані)
#
# [Випадки використання](#випадки-використання)
# [1. Підсумовування тексту](#1.-підсумовування-тексту)
# [2. Класифікація тексту](#2.-класифікація-тексту)
# [3. Генерація нових назв продуктів](#3.-генерація-нових-назв-продуктів)
# [4. Тонке налаштування класифікатора](#4.тонке-налаштування-класифікатора)
#
# [Посилання](#посилання)
#
# ### Побудуйте свій перший промпт
# Ця коротка вправа надасть базове введення для подання промптів моделі в Github Models для простого завдання "підсумовування".

# %% [markdown]
# **Кроки**:
# 1. Встановіть бібліотеку `azure-ai-inference` у своєму середовищі Python, якщо ви ще цього не зробили.
# 2. Завантажте стандартні допоміжні бібліотеки та налаштуйте облікові дані для Github Models.
# 3. Виберіть модель для вашого завдання
# 4. Створіть простий промпт для моделі
# 5. Надішліть запит до API моделі!
#
# ### 1. Встановіть `azure-ai-inference`

# %%
# %pip install azure-ai-inference
# Out:
# Requirement already satisfied: azure-ai-inference in /usr/local/python/3.12.1/lib/python3.12/site-packages (1.0.0b9)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (1.36.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from azure-ai-inference) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-core>=1.30.0->azure-ai-inference) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-inference) (2025.4.26)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Імпортуйте допоміжні бібліотеки та створіть облікові дані

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.ai.inference.models import SystemMessage, UserMessage
from azure.core.credentials import AzureKeyCredential

token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.inference.ai.azure.com"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

# %% [markdown]
# ### 3. Пошук правильної моделі
# Моделі GPT-3.5-turbo або GPT-4 можуть розуміти та генерувати природну мову.

# %%
# Виберіть модель загального призначення curie для тексту
model_name = "gpt-4o"

# %% [markdown]
# ## 4. Дизайн промпту
#
# "Магія великих мовних моделей полягає в тому, що, навчаючись мінімізувати цю похибку передбачення на великих обсягах тексту, моделі в результаті вивчають концепції, корисні для цих передбачень. Наприклад, вони вивчають такі концепції як"(1):
#
# * як правильно писати
# * як працює граматика
# * як перефразовувати
# * як відповідати на запитання
# * як вести розмову
# * як писати багатьма мовами
# * як кодувати
# * тощо.
#
# #### Як керувати великою мовною моделлю
# "З усіх входів до великої мовної моделі, безумовно, найбільш впливовим є текстовий промпт"(1).
#
# Великі мовні моделі можна спонукати до створення виводу кількома способами:
#
# Інструкція: Скажіть моделі, що ви хочете
# Завершення: Спонукайте модель завершити початок того, що ви хочете
# Демонстрація: Покажіть моделі, що ви хочете, за допомогою:
# Кількох прикладів у промпті
# Багатьох сотень або тисяч прикладів у навчальному наборі даних для тонкого налаштування"

# %% [markdown]
# #### Існують три основні рекомендації щодо створення промптів:
#
# **Показуйте та розповідайте**. Чітко вказуйте, що ви хочете, через інструкції, приклади або їх комбінацію. Якщо ви хочете, щоб модель розташувала список елементів в алфавітному порядку або класифікувала абзац за настроєм, покажіть їй, що саме ви хочете.
#
# **Надавайте якісні дані**. Якщо ви намагаєтеся створити класифікатор або змусити модель слідувати певній схемі, переконайтеся, що є достатньо прикладів. Обов'язково перевірте свої приклади — модель зазвичай достатньо розумна, щоб зрозуміти основні орфографічні помилки та дати вам відповідь, але вона також може припустити, що це навмисно, і це може вплинути на відповідь.
#
# **Перевіряйте налаштування**. Параметри temperature та top_p контролюють, наскільки детермінованою є модель при генерації відповіді. Якщо ви просите відповідь, де є лише одна правильна відповідь, то вам варто встановити їх нижче. Якщо ви шукаєте більш різноманітні відповіді, то можливо вам захочеться встановити їх вище. Найпоширенішою помилкою, яку люди роблять з цими налаштуваннями, є припущення, що вони є елементами керування "розумністю" або "креативністю".

# %% [markdown]
# Джерело: https://github.com/Azure/OpenAI/blob/main/How%20to/Completions.md
#
# ### 5. Надсилаємо!

# %%
# Створіть свій перший промпт
text_prompt = "Should oxford commas always be used?"

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content
# Out:
# 'The use of the Oxford comma depends on context, style guidelines, and personal preference. While it\'s not mandatory to always use it, there are good reasons why many choose to do so.\n\n### What is the Oxford Comma?\nThe Oxford comma (or serial comma) is the final comma placed before the coordinating conjunction (like "and" or "or") in a list of three or more items. For example:\n- With Oxford comma: "I love apples, oranges, and bananas."\n- Without Oxford comma: "I love apples, oranges and bananas."\n\n### Arguments *For* Using the Oxford Comma:\n1. **Clarity and Avoiding Ambiguity**:\n   Including the Oxford comma can prevent misinterpretation. For example:\n   - Without an Oxford comma: "I’d like to thank my parents, Oprah Winfrey and God."\n     (This could imply that Oprah Winfrey and God are your parents.)\n   - With Oxford comma: "I’d like to thank my parents, Oprah Winfrey, and God."\n     (It’s clear these are three distinct entities.)\n   \n2. **Consistency**:\n   Some prefer to always use the Oxford comma because it creates a consistent rule for handling lists.\n\n3. **Style Standards**:\n   Certain style guides, such as the **Oxford University Press style guide, The Chicago Manual of Style, and APA Style**, recommend or mandate the use of the Oxford comma.\n\n### Arguments *Against* Using the Oxford Comma:\n1. **Not Always Necessary**:\n   In many cases, the meaning of the sentence is clear without it. For example:\n   - "I love apples, oranges and bananas." (This is generally understood as a simple list.)\n   \n2. **Conciseness**:\n   Omitting the Oxford comma can make sentences shorter and more streamlined, which is a preference in some styles, like the **AP Stylebook**.\n\n3. **Personal or Regional Preferences**:\n   Style guides and practices differ. For instance, American English often favors the Oxford comma, while British English tends to omit it (except when needed for clarity).\n\n### When Should It Be Used?\n- If following a specific style guide, adhere to its rules.\n- Use it if there\'s any chance of confusion or ambiguity without it.\n- If you want to promote clarity and consistency, it’s a good idea to use the Oxford comma by default.\n\nIn conclusion, while the Oxford comma isn\'t always required, it’s often helpful and is favored in many situations. Consistency and clarity are the most important considerations, so use your judgment based on the context and audience!'

# %% [markdown]
# ### Повторіть той самий виклик, як порівнюються результати?

# %%
response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":text_prompt},])

response.choices[0].message.content
# Out:
# 'The use of the Oxford comma (also known as the serial comma) is a stylistic choice and not universally required, but its use is often recommended for clarity and avoiding ambiguity in certain situations. The Oxford comma is the comma that comes before the final conjunction (such as *and* or *or*) in a list of three or more items. For example:\n\n- With Oxford comma: "I love my parents, Oprah, and Beyoncé."\n- Without Oxford comma: "I love my parents, Oprah and Beyoncé."\n\nIn the example without the Oxford comma, it could be interpreted as "my parents" being Oprah and Beyoncé, which may not be the intended meaning.\n\n### Arguments for Using the Oxford Comma:\n1. **Clarity:** It helps avoid misinterpretations or ambiguity, especially in complex lists.\n2. **Consistency:** It creates a standardized approach that prevents confusion across various sentences and contexts.\n3. **Professional Standards:** Many style guides, such as *The Chicago Manual of Style* and *The Oxford University Press Style Guide*, recommend using it.\n\n### Arguments Against the Oxford Comma:\n1. **Conciseness:** Some argue that omitting the Oxford comma makes sentences cleaner and less cluttered.\n2. **Not Always Necessary:** In some contexts, the meaning is clear without it, especially in simple lists.\n3. **Style Choice:** Publications like the *Associated Press Stylebook* typically omit the Oxford comma unless needed for clarity.\n\n### When Should It Always Be Used?\nEven if you or your organization doesn\'t routinely use the Oxford comma, it\'s advisable to include it in cases where leaving it out might lead to ambiguity or confusion. For example:\n\n- Ambiguous: "We invited the strippers, JFK and Stalin."\n  (This could imply that JFK and Stalin are the strippers.)\n- Clear with Oxford comma: "We invited the strippers, JFK, and Stalin."\n\n### Conclusion:\nWhile the Oxford comma isn\'t "mandatory," its use is highly recommended in most formal or professional writing. If you\'re unsure, it\'s generally better to include the Oxford comma to ensure clarity and consistency. Many people adopt a flexible approach: always using it unless following specific style guide rules (e.g., AP Style), or omitting it when the context is unambiguous.'

# %% [markdown]
# ## Підсумовування тексту
# #### Завдання
# Підсумуйте текст, додавши 'tl;dr:' в кінці текстового уривку. Зверніть увагу, як модель розуміє, як виконувати низку завдань без додаткових інструкцій. Ви можете експериментувати з більш описовими промптами, ніж tl;dr, щоб модифікувати поведінку моделі та налаштувати підсумок, який ви отримуєте(3).
#
# Останні роботи продемонстрували значні успіхи в багатьох завданнях та тестах NLP шляхом попереднього навчання на великому корпусі тексту з подальшим тонким налаштуванням на конкретне завдання. Хоча зазвичай архітектура не залежить від завдання, цей метод все ще вимагає наборів даних для тонкого налаштування, специфічних для завдання, які містять тисячі або десятки тисяч прикладів. На відміну від цього, люди зазвичай можуть виконувати нове мовне завдання лише з кількох прикладів або з простих інструкцій - щось, з чим поточні системи NLP все ще значною мірою борються. Тут ми показуємо, що масштабування мовних моделей значно покращує ефективність, не залежну від завдання, з кількома прикладами, іноді навіть досягаючи конкурентоспроможності з попередніми найсучаснішими підходами тонкого налаштування.
#
# Tl;dr
#
# # Вправи для кількох випадків використання
# 1. Підсумовування тексту
# 2. Класифікація тексту
# 3. Генерація нових назв продуктів

# %%
prompt = "Recent work has demonstrated substantial gains on many NLP tasks and benchmarks by pre-training on a large corpus of text followed by fine-tuning on a specific task. While typically task-agnostic in architecture, this method still requires task-specific fine-tuning datasets of thousands or tens of thousands of examples. By contrast, humans can generally perform a new language task from only a few examples or from simple instructions - something that current NLP systems still largely struggle to do. Here we show that scaling up language models greatly improves task-agnostic, few-shot performance, sometimes even reaching competitiveness with prior state-of-the-art fine-tuning approaches.\n\nTl;dr"

# %%
#Встановлення кількох додаткових типових параметрів під час виклику API

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content
# Out:
# 'Scaling up language models significantly improves task-agnostic, few-shot performance, enabling them to perform well on new language tasks with limited examples or simple instructions, sometimes rivaling state-of-the-art fine-tuning methods.'

# %% [markdown]
# ## Класифікація тексту
# #### Завдання
# Класифікуйте елементи на категорії, надані під час виведення. У наступному прикладі ми надаємо як категорії, так і текст для класифікації у промпті(*playground_reference).
#
# Запит клієнта: Привіт, одна з клавіш на клавіатурі мого ноутбука нещодавно зламалася, і мені потрібна заміна:
#
# Класифікована категорія:

# %%
prompt = "Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]\n\ninquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:\n\nClassified category:"
print(prompt)
# Out:
# Classify the following inquiry into one of the following: categories: [Pricing, Hardware Support, Software Support]
#
# inquiry: Hello, one of the keys on my laptop keyboard broke recently and I'll need a replacement:
#
# Classified category:

# %%
#Встановлення кількох додаткових типових параметрів під час виклику API

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt},])

response.choices[0].message.content
# Out:
# 'Classified category: Hardware Support'

# %% [markdown]
# ## Генерація нових назв продуктів
# #### Завдання
# Створіть назви продуктів з прикладів слів. Тут ми включаємо в промпт інформацію про продукт, для якого ми збираємося генерувати назви. Ми також надаємо схожий приклад, щоб показати схему, яку ми хочемо отримати. Ми також встановили високе значення температури, щоб збільшити випадковість та отримати більш інноваційні відповіді.
#
# Опис продукту: Домашній міксер для молочних коктейлів
# Ключові слова: швидкий, здоровий, компактний.
# Назви продуктів: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Опис продукту: Пара взуття, яка може підходити для будь-якого розміру стопи.
# Ключові слова: адаптивний, що підходить, omni-fit.

# %%
prompt = "Product description: A home milkshake maker\nSeed words: fast, healthy, compact.\nProduct names: HomeShaker, Fit Shaker, QuickShake, Shake Maker\n\nProduct description: A pair of shoes that can fit any foot size.\nSeed words: adaptable, fit, omni-fit."

print(prompt)
# Out:
# Product description: A home milkshake maker
# Seed words: fast, healthy, compact.
# Product names: HomeShaker, Fit Shaker, QuickShake, Shake Maker
#
# Product description: A pair of shoes that can fit any foot size.
# Seed words: adaptable, fit, omni-fit.

# %%
#Встановлення кількох додаткових типових параметрів під час виклику API

response = client.complete(
  model=model_name,
  messages = [{"role":"system", "content":"You are a helpful assistant."},
               {"role":"user","content":prompt}])

response.choices[0].message.content
# Out:
# 'Product Names: OmniFit, FlexiStep, AdaptiveSole, FitAll'

# %% [markdown]
# ## Індивідуальне завдання
#
#
# > Розробіть додаток, що допомагає користувачам створювати короткі огляди на технічні статті.

# %%
import os
from azure.ai.inference import ChatCompletionsClient
from azure.core.credentials import AzureKeyCredential

# Додаток-помічник для створення коротких оглядів технічних статей

token = os.environ["GITHUB_TOKEN"]
endpoint = "https://models.inference.ai.azure.com"

client = ChatCompletionsClient(
    endpoint=endpoint,
    credential=AzureKeyCredential(token),
)

system_prompt = (
    "Ти — асистент, який допомагає користувачам створювати короткі огляди технічних статей. "
    "Користувач надсилає тобі фрагмент статті, конспект або витримку з документації.\n"
    "Твої завдання:\n"
    "1) Визначити тему та основну ідею матеріалу.\n"
    "2) Виділити ключові технічні моменти та внесок авторів.\n"
    "3) Сформувати стислий огляд у 3–5 реченнях простою мовою: "
    "про що стаття, де це може застосовуватися, які сильні сторони та можливі обмеження.\n"
    "4) Наприкінці наведи 3 пунктами: «Що варто запам’ятати».\n"
    "Пиши українською, структуровано та без зайвої води."
)


def build_user_request(article_text: str) -> str:
    return (
        "Ось текст технічної статті, фрагмент або конспект:\n\n"
        f"{article_text}\n\n"
        "На основі цього зроби короткий огляд за правилами із системного повідомлення. "
        "Не переповідай текст дослівно, а узагальни найважливіші ідеї."
    )


print("Помічник для створення коротких оглядів технічних статей.")
print("Встав текст статті / конспект (або натисни Enter, щоб вийти).\n")

raw_input_text = input("Текст статті / нотатки:\n").strip()

if not raw_input_text:
    print("Завершення роботи помічника.")
else:
    user_message = build_user_request(raw_input_text)

    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_message},
    ]

    print("\nAI формує огляд статті...\n")

    response = client.complete(
        model="gpt-4o",
        max_tokens=800,
        temperature=0.3,
        messages=messages,
    )

    assistant_message = response.choices[0].message

    print("Огляд статті:\n")
    print(assistant_message.content)
    print("\n" + "-" * 60 + "\n")

    # Збереження відповіді в історію (на випадок подальшого розвитку діалогу)
    messages.append({
        "role": "assistant",
        "content": assistant_message.content
    })
# Out:
# Чат для класифікації помилок компіляції.
# Встав текст помилки (або просто натисни Enter, щоб вийти).
#
#
# AI аналізує помилку...
#
# AI-відповідь:
#
# 1) **Мова програмування**: Java
# 2) **Класифікація помилки**: Синтаксична помилка
# 3) **Причина**: Ви написали `System.otl.println` замість правильного `System.out.println`. Метод `otl` не існує в класі `PrintStream`.
# 4) **Виправлення**: Замініть `otl` на `out`.
#    ```java
#    System.out.println("Test message");
#    ```
#
# ------------------------------------------------------------
